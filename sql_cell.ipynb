# %%
# %pip install jupysql duckdb duckdb-engine --quiet
# %load_ext sql
# %sql duckdb://
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 863.4 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 7.5 MB/s eta 0:00:00
# Connecting to 'duckdb://'

# %%
from urllib.request import urlretrieve

_ = urlretrieve(
    "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv",
    "penguins.csv",
)

# %%
# %%sql
# CREATE TABLE penguins AS SELECT * FROM penguins.csv
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %sqlcmd tables
# Out:
# +----------+
# |   Name   |
# +----------+
# | penguins |
# +----------+

# %%
# %sqlcmd columns -t penguins
# Out:
# +-------------------+---------+----------+---------+---------------+---------+
# |        name       |   type  | nullable | default | autoincrement | comment |
# +-------------------+---------+----------+---------+---------------+---------+
# |      species      | VARCHAR |   True   |   None  |     False     |   None  |
# |       island      | VARCHAR |   True   |   None  |     False     |   None  |
# |   bill_length_mm  |  FLOAT  |   True   |   None  |     False     |   None  |
# |   bill_depth_mm   |  FLOAT  |   True   |   None  |     False     |   None  |
# | flipper_length_mm |  BIGINT |   True   |   None  |     False     |   None  |
# |    body_mass_g    |  BIGINT |   True   |   None  |     False     |   None  |
# |        sex        | VARCHAR |   True   |   None  |     False     |   None  |
# +-------------------+---------+----------+---------+---------------+---------+

# %%
# %%sql
# SELECT *
# FROM penguins.csv
# LIMIT 3
# Out:
# Running query in 'duckdb://'
# +---------+-----------+----------------+---------------+-------------------+-------------+--------+
# | species |   island  | bill_length_mm | bill_depth_mm | flipper_length_mm | body_mass_g |  sex   |
# +---------+-----------+----------------+---------------+-------------------+-------------+--------+
# |  Adelie | Torgersen |      39.1      |      18.7     |        181        |     3750    |  MALE  |
# |  Adelie | Torgersen |      39.5      |      17.4     |        186        |     3800    | FEMALE |
# |  Adelie | Torgersen |      40.3      |      18.0     |        195        |     3250    | FEMALE |
# +---------+-----------+----------------+---------------+-------------------+-------------+--------+

# %%
# %sql duckdb:////content/abu.duckdb
# Out:
# Connecting and switching to connection 'duckdb:////content/abu.duckdb'

# %%
# %%sql
# drop table if exists x;
# create table x(a integer);
# Out:
# Running query in 'duckdb:////content/abu.duckdb'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# insert into x (a) values(1);
# Out:
# Running query in 'duckdb:////content/abu.duckdb'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# select * from x;
# Out:
# Running query in 'duckdb:////content/abu.duckdb'
# +---+
# | a |
# +---+
# | 1 |
# +---+

# %%
# %%sql
# CREATE TABLE penguins AS SELECT * FROM penguins.csv
# Out:
# Running query in 'duckdb:////content/abu.duckdb'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT *
# FROM penguins
# LIMIT 3
# Out:
# Running query in 'duckdb:////content/abu.duckdb'
# +---------+-----------+----------------+---------------+-------------------+-------------+--------+
# | species |   island  | bill_length_mm | bill_depth_mm | flipper_length_mm | body_mass_g |  sex   |
# +---------+-----------+----------------+---------------+-------------------+-------------+--------+
# |  Adelie | Torgersen |      39.1      |      18.7     |        181        |     3750    |  MALE  |
# |  Adelie | Torgersen |      39.5      |      17.4     |        186        |     3800    | FEMALE |
# |  Adelie | Torgersen |      40.3      |      18.0     |        195        |     3250    | FEMALE |
# +---------+-----------+----------------+---------------+-------------------+-------------+--------+
